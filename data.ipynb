# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/MTG/mtg-jamendo-dataset.git
# Out:
# Cloning into 'mtg-jamendo-dataset'...
# remote: Enumerating objects: 1283, done.
# remote: Counting objects: 100% (253/253), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 1283 (delta 241), reused 224 (delta 224), pack-reused 1030 (from 1)
# Receiving objects: 100% (1283/1283), 42.37 MiB | 19.86 MiB/s, done.
# Resolving deltas: 100% (787/787), done.
# Updating files: 100% (186/186), done.

# %%
# !ls
# Out:
# drive  mtg-jamendo-dataset  sample_data

# %%
# %cd mtg-jamendo-dataset/scripts/download
# Out:
# /content/mtg-jamendo-dataset/scripts/download

# %%
# !python3 mtg-jamendo-dataset/scripts/download/download.py -h
# Out:
# usage: download.py [-h] [--dataset {raw_30s,autotagging_moodtheme}]
#                    [--type {audio,audio-low,melspecs,acousticbrainz}]
#                    [--from {mtg,mtg-fast}] [--unpack] [--remove]
#                    outputdir
#
# Download the MTG-Jamendo dataset
#
# positional arguments:
#   outputdir             directory to store the dataset
#
# options:
#   -h, --help            show this help message and exit
#   --dataset {raw_30s,autotagging_moodtheme}
#                         dataset to download (default: raw_30s)
#   --type {audio,audio-low,melspecs,acousticbrainz}
#                         type of data to download (audio, audio in low quality,
#                         mel-spectrograms, AcousticBrainz features) (default:
#                         audio)
#   --from {mtg,mtg-fast}
#                         download from MTG (server in Spain, slow), or fast MTG
#                         mirror (Finland) (default: mtg-fast)
# ...

# %%
# !python3 download.py --dataset raw_30s --type audio-low --from mtg --unpack --remove "/content/drive/MyDrive/tag-polysemy/mtg-audio-low"
# Out:
# ...
# Downloading...
# From: https://essentia.upf.edu/documentation/datasets/mtg-jamendo/raw_30s/audio-low/raw_30s_audio-low-00.tar
# To: /content/drive/MyDrive/tag-polysemy/mtg-audio-low2/raw_30s_audio-low-00.tar
# 100% 1.66G/1.66G [01:05<00:00, 25.4MB/s]
# raw_30s_audio-low-00.tar checksum OK
# Downloading...
# From: https://essentia.upf.edu/documentation/datasets/mtg-jamendo/raw_30s/audio-low/raw_30s_audio-low-01.tar
# To: /content/drive/MyDrive/tag-polysemy/mtg-audio-low2/raw_30s_audio-low-01.tar
# 100% 1.60G/1.60G [01:20<00:00, 19.9MB/s]
# raw_30s_audio-low-01.tar checksum OK
# Downloading...
# From: https://essentia.upf.edu/documentation/datasets/mtg-jamendo/raw_30s/audio-low/raw_30s_audio-low-02.tar
# To: /content/drive/MyDrive/tag-polysemy/mtg-audio-low2/raw_30s_audio-low-02.tar
# 100% 1.71G/1.71G [01:13<00:00, 23.1MB/s]
# raw_30s_audio-low-02.tar checksum OK
# Downloading...
# ...
